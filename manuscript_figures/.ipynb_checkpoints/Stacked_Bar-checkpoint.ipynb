# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# library(phyloseq)
# library(plyr)
# library(dplyr); library(tidyr)
# library(ggplot2)
# library(rwantshue)

# %%
# %%R
# physeq = import_biom("../../SeqData/otu_table.tax.meta.biom", "../../SeqData/fulltree.tre", parseFunction = parse_taxonomy_greengenes)
#
# Merge<-paste(as.character(sample_data(physeq)$Trtmt),as.character(sample_data(physeq)$Month),as.character(sample_data(physeq)$Cosm),sep="_")
# sample_data(physeq)$Merge <- Merge
# # Creating a new column in the phyloseq sample data called Merge,
# # which contains a concatenated ID so all samples from the same mineral, month, and cosm
# # will have the same ID (thus merging PCR and buffer replicates).
#
# ps.merged = merge_samples(physeq, "Merge")
# # Merging the phyloseq object by biological replicates
#
# keep=c("Cosm","Month","Trtmt")
# sd = sample_data(ps.merged)
# sd = sd[,keep]
# sd$Trtmt = substring(row.names(sd),1,1)
# sd$Trtmt[sd$Trtmt=="B"]="Blank"
# sd$Trtmt[sd$Trtmt=="F"]="Ferrihydrite"
# sd$Trtmt[sd$Trtmt=="Q"]="Quartz"
# sd$Trtmt[sd$Trtmt=="H"]="Heavy Fraction"
# sd$Trtmt[sd$Trtmt=="S"]="Soil"
# sd$Trtmt[sd$Trtmt=="K"]="Kaolinite"
# sample_data(ps.merged) = sd
# physeq = ps.merged

# %%
# %%R
# physeq.noSmall <- subset_samples(physeq,sample_sums(physeq)>=1500)

# %%
# %%R
# mdf = psmelt(physeq)

# %%
# %%R -w 1500 -h 700
#
# cutoff = 0.01
# totabund = 00
#
# d.plot = mdf %>%
#     group_by(Sample) %>%
#     filter(sum(Abundance)>totabund) %>%
#     mutate(Abundance = Abundance / sum(Abundance)) %>%
#     group_by(Sample, Class, Trtmt) %>%
#     summarize(Abundance = sum(Abundance)) %>%
#     filter(Abundance > cutoff) %>%
#     arrange(Trtmt)
#
# colnames(d.plot) <- c("Sample", "Tax", "Trtmt", "Abundance")
#
# mean.Abund = ddply(d.plot, .(Tax), summarize, M = mean(Abundance))
# # Calculate the phyla's mean abundances
# d.plot$Tax = factor(d.plot$Tax, levels=mean.Abund[order(-mean.Abund$M),]$Tax)
# # Order the Phyla by abundance
#
# d.plot$Trtmt = ordered(d.plot$Trtmt, levels = c("Ferrihydrite", "Quartz", "Kaolinite", "Heavy Fraction", "Soil"))
#
# d.plot<-d.plot[with(d.plot, order(Trtmt, Sample, Tax)),]
# # Sort the whole dataframe by this phylum order
#
# scheme <- iwanthue()
# colors = scheme$hex(length(unique(d.plot$Tax)), color_space = hcl_presets$pastel)
#
# p = ggplot(d.plot, aes(x = Sample, y = Abundance, fill = Tax))
#
# p = p + facet_grid(. ~Trtmt, scales = "free_x", space = "free")
#
# p = p + scale_fill_manual(values = colors)
#
# p = p + geom_bar(stat = "identity", width = 0.70)
#
# p = p + guides(fill = guide_legend(ncol = 5))
#
# #p = p + theme(axis.text.x=theme_text(angle=-90))
#
# p = p + theme_bw()
#
# p = p + theme(legend.position="bottom")
#
# p

# %%
# %%R -w 900 -h 600
#
# cutoff = 0.00
# totabund = 1500
#
# d.plot = mdf %>%
#     group_by(Sample) %>%
#     filter(sum(Abundance) > totabund) %>%
#     mutate(Abundance = Abundance / sum(Abundance))
# d.plot$Phylum = ifelse(is.na(d.plot$Phylum)==TRUE, "Unidentified", paste(d.plot$Phylum))
# d.plot$Phylum = ifelse(d.plot$Phylum=="unidentified", "Unidentified", paste(d.plot$Phylum))
# d.plot = d.plot %>%
#     group_by(Trtmt, Phylum, OTU) %>%
#     summarize(Abundance = mean(Abundance)) %>%
#     group_by(Trtmt, Phylum) %>%
#     summarize(Abundance = sum(Abundance)) %>%
#     filter(Abundance > cutoff) %>%
#     arrange(Trtmt) %>%
#     group_by(Trtmt,Phylum)%>%
#     summarize(Abundance = mean(Abundance))
#
# colnames(d.plot) <- c("Trtmt", "Tax", "Abundance")
#
# mean.Abund = ddply(d.plot, .(Tax), summarize, M = mean(Abundance))
# # Calculate the phyla's mean abundances
# d.plot$Tax = factor(d.plot$Tax, levels=mean.Abund[order(-mean.Abund$M),]$Tax)
# # Order the Phyla by abundance
#
# d.plot$Trtmt = ordered(d.plot$Trtmt, levels = c("Ferrihydrite", "Quartz", "Kaolinite", "Heavy Fraction", "Soil"))
#
# d.plot<-d.plot[with(d.plot, order( Trtmt, Tax)),]
# # Sort the whole dataframe by this phylum order
#
# scheme <- iwanthue()
# colors = scheme$hex(length(unique(d.plot$Tax)), color_space = hcl_presets$pastel)
#
# p = ggplot(d.plot, aes(x = Trtmt, y = Abundance, fill = Tax))
#
# #p = p + facet_grid(. ~Trtmt, scales = "free_x", space = "free")
#
# N=10
# Phyla=factor(d.plot$Tax, d.plot[order(-d.plot$Abundance),]$Tax)[1:N]
# p = p + scale_fill_manual(values = colors, breaks = Phyla)
#
# p = p + geom_bar(stat = "identity", width = 0.70)
#
# p = p + guides(fill = guide_legend(ncol = 1, title = "Phylum", reverse="TRUE"))
#
# #p = p + theme(axis.text.y=theme_text(angle=-90))
#
# p = p + ylab("Mean relative abundance") + xlab("")
#
# p = p + theme_bw()
#
# p = p + theme(axis.text.x = element_text(size = 14, angle = 45, hjust=1),
#               axis.text.y = element_text(size = 14),
#               axis.title.x = element_text(size = 28),
#               axis.title.y = element_text(size = 32,vjust=1,face='bold'),
#               legend.title = element_text(size=22),
#               legend.text = element_text(size = 16))
#
# p = p + theme(legend.position="right", panel.grid.major= element_blank())
#
# p

# %%
# %%R
# ggsave(filename="RelabundPhylum16SCombMonths.jpg", p, width=7, height=8.6)

# %% [markdown]
# ### Making box charts instead of stacked

# %%
# %%R
# d = mdf %>%
#     filter(Month!=2.0)%>%
#     group_by(Phylum) %>%
#     summarize(Abundance = sum(Abundance))
# Porder = na.omit(d$Phylum[order(-d$Abundance)])
# Porder
# # Ordering the phyla roughly in order of total abundance
# Out:
#  [1] Proteobacteria   Actinobacteria   Bacteroidetes    Firmicutes
#  [5] Acidobacteria    Planctomycetes   Verrucomicrobia  Chloroflexi
#  [9] Chlamydiae       TM6              Gemmatimonadetes Armatimonadetes
# [13] Cyanobacteria    Fibrobacteres    Chlorobi         Crenarchaeota
# [17] FBP              Nitrospirae      OD1              TM7
# [21] BRC1             BHI80-139        NKB19            Elusimicrobia
# [25] [Thermi]         WPS-2            Tenericutes      Aquificae
# [29] Fusobacteria     AD3              WS3              OP11
# [33] WS2              Spirochaetes     WWE1             OP3
# [37] Synergistetes    Euryarchaeota    GN02             SR1
# [41] Lentisphaerae    Thermotogae      Deferribacteres  OP8
# [45] Dictyoglomi      FCPU426          NC10             OP1
# [49] WS4              GN04             Chrysiogenetes   [Parvarchaeota]
# [53] SAR406           SBR1093          Caldiserica      [Caldithrix]
# [57] GOUTA4           OP9              GAL15            WS1
# [61] AncK6            OC31             AC1              Kazan-3B-28
# 64 Levels: [Caldithrix] [Parvarchaeota] [Thermi] AC1 ... WWE1

# %%
# %%R
# Porder[Porder!="Chlamydiae"]
# Out:
#  [1] Proteobacteria   Actinobacteria   Bacteroidetes    Firmicutes
#  [5] Acidobacteria    Planctomycetes   Verrucomicrobia  Chloroflexi
#  [9] TM6              Gemmatimonadetes Armatimonadetes  Cyanobacteria
# [13] Fibrobacteres    Chlorobi         Crenarchaeota    FBP
# [17] Nitrospirae      OD1              TM7              BRC1
# [21] BHI80-139        NKB19            Elusimicrobia    [Thermi]
# [25] WPS-2            Tenericutes      Aquificae        Fusobacteria
# [29] AD3              WS3              OP11             WS2
# [33] Spirochaetes     WWE1             OP3              Synergistetes
# [37] Euryarchaeota    GN02             SR1              Lentisphaerae
# [41] Thermotogae      Deferribacteres  OP8              Dictyoglomi
# [45] FCPU426          NC10             OP1              WS4
# [49] GN04             Chrysiogenetes   [Parvarchaeota]  SAR406
# [53] SBR1093          Caldiserica      [Caldithrix]     GOUTA4
# [57] OP9              GAL15            WS1              AncK6
# [61] OC31             AC1              Kazan-3B-28
# 63 Levels: [Caldithrix] [Parvarchaeota] [Thermi] AC1 ... WWE1

# %%
# %%R
#
# # Setting up the data so we don't have to re-run each time
# Porder = Porder[Porder!="Chlamydiae"]
# # Cutting out Chlamydiae b/c it's largely from weird HF sample
#
# cutoff = 0.01
# totabund = 1500
# nphyla = 10
#
# Porder = Porder[1:nphyla]
# # Selects only the Phyla from the top nphyla (usu. 10)
#
#
# # For a given sample, I want to make sure that if a phylum from my list is not present,
# # we assign it a value of zero. I guess we need to get all the sample IDs
#
# d.plot = mdf %>%
#     group_by(Sample) %>%
#     mutate(Abundance = Abundance / sum(Abundance)) %>%
#     filter(Month != 2.0)%>%
#     group_by(Phylum, Sample, Trtmt) %>%
#     summarize(Abundance = sum(Abundance)) %>%
#     filter(Abundance > cutoff) %>%
#     filter(Phylum %in% Porder)%>%
#     arrange(Trtmt, Abundance)
#
# d.plot$Phylum = factor(d.plot$Phylum, levels = Porder)
# d.plot = d.plot[with(d.plot, order(d.plot$Phylum)),]
# d.plot$Trtmt = factor(d.plot$Trtmt, levels = c("Ferrihydrite", "Quartz", "Kaolinite", "Heavy Fraction", "Soil"))
# # Changing labels, setting orders, etc.
#
# d.plot = d.plot %>%
#     expand(Sample, Phylum) %>%
#     left_join(d.plot)%>%
#     group_by(Sample, Phylum, Trtmt)%>%
#     summarise(Abundance = sum(Abundance, na.rm=TRUE))
# # Taking the data, and making all possible combinations of sample, phylum, and treatment
# # Then, we match up our actual data with our abundance counts, etc.
# # And, we don't want there to be NAs, so we sum the total for each possibility
#
# # But we also need non-presences to be counted.
#
# SampTrtmt = na.omit(unique(d.plot[c("Sample", "Trtmt")]))
# # Creating a list of sample IDs matched with their treatment
#
# d.plot = merge(d.plot[,c(1,2,4)], SampTrtmt, by="Sample")
# # Merging the two tables, but forgetting the old Trtmt column
# d.plot
# Out:
# Joining by: c("Sample", "Phylum")
#       Sample           Phylum  Abundance          Trtmt
# 1   F_2.5_13   Proteobacteria 0.82902432   Ferrihydrite
# 2   F_2.5_13   Actinobacteria 0.03940628   Ferrihydrite
# 3   F_2.5_13    Bacteroidetes 0.07058444   Ferrihydrite
# 4   F_2.5_13       Firmicutes 0.00000000   Ferrihydrite
# 5   F_2.5_13    Acidobacteria 0.00000000   Ferrihydrite
# 6   F_2.5_13   Planctomycetes 0.00000000   Ferrihydrite
# 7   F_2.5_13  Verrucomicrobia 0.01214052   Ferrihydrite
# 8   F_2.5_13      Chloroflexi 0.00000000   Ferrihydrite
# 9   F_2.5_13              TM6 0.00000000   Ferrihydrite
# 10  F_2.5_13 Gemmatimonadetes 0.00000000   Ferrihydrite
# 11  F_2.5_14   Proteobacteria 0.58932416   Ferrihydrite
# 12  F_2.5_14   Actinobacteria 0.11775404   Ferrihydrite
# 13  F_2.5_14    Bacteroidetes 0.17309823   Ferrihydrite
# 14  F_2.5_14       Firmicutes 0.01150783   Ferrihydrite
# 15  F_2.5_14    Acidobacteria 0.00000000   Ferrihydrite
# 16  F_2.5_14   Planctomycetes 0.02947509   Ferrihydrite
# 17  F_2.5_14  Verrucomicrobia 0.01716245   Ferrihydrite
# 18  F_2.5_14      Chloroflexi 0.00000000   Ferrihydrite
# 19  F_2.5_14              TM6 0.01184230   Ferrihydrite
# 20  F_2.5_14 Gemmatimonadetes 0.00000000   Ferrihydrite
# 21  F_2.5_16   Proteobacteria 0.43249527   Ferrihydrite
# 22  F_2.5_16   Actinobacteria 0.23891527   Ferrihydrite
# 23  F_2.5_16    Bacteroidetes 0.22451759   Ferrihydrite
# 24  F_2.5_16       Firmicutes 0.02427845   Ferrihydrite
# 25  F_2.5_16    Acidobacteria 0.01313561   Ferrihydrite
# 26  F_2.5_16   Planctomycetes 0.01193995   Ferrihydrite
# 27  F_2.5_16  Verrucomicrobia 0.01315221   Ferrihydrite
# 28  F_2.5_16      Chloroflexi 0.00000000   Ferrihydrite
# 29  F_2.5_16              TM6 0.00000000   Ferrihydrite
# 30  F_2.5_16 Gemmatimonadetes 0.00000000   Ferrihydrite
# 31  F_2.5_27   Proteobacteria 0.55445088   Ferrihydrite
# 32  F_2.5_27   Actinobacteria 0.11728621   Ferrihydrite
# 33  F_2.5_27    Bacteroidetes 0.12538220   Ferrihydrite
# 123   F_3_23    Bacteroidetes 0.01796226   Ferrihydrite
# 124   F_3_23       Firmicutes 0.04947182   Ferrihydrite
# 125   F_3_23    Acidobacteria 0.03223530   Ferrihydrite
# 126   F_3_23   Planctomycetes 0.01832514   Ferrihydrite
# 127   F_3_23  Verrucomicrobia 0.01310378   Ferrihydrite
# 128   F_3_23      Chloroflexi 0.01399081   Ferrihydrite
# 129   F_3_23              TM6 0.00000000   Ferrihydrite
# 130   F_3_23 Gemmatimonadetes 0.00000000   Ferrihydrite
# 131   F_3_44   Proteobacteria 0.70963515   Ferrihydrite
# 132   F_3_44   Actinobacteria 0.04090980   Ferrihydrite
# 133   F_3_44    Bacteroidetes 0.21802989   Ferrihydrite
# 134   F_3_44       Firmicutes 0.00000000   Ferrihydrite
# 135   F_3_44    Acidobacteria 0.00000000   Ferrihydrite
# 136   F_3_44   Planctomycetes 0.00000000   Ferrihydrite
# 137   F_3_44  Verrucomicrobia 0.00000000   Ferrihydrite
# 138   F_3_44      Chloroflexi 0.00000000   Ferrihydrite
# 139   F_3_44              TM6 0.00000000   Ferrihydrite
# 140   F_3_44 Gemmatimonadetes 0.00000000   Ferrihydrite
# 141 H_2.5_13   Proteobacteria 0.59835208 Heavy Fraction
# 142 H_2.5_13   Actinobacteria 0.13484175 Heavy Fraction
# 143 H_2.5_13    Bacteroidetes 0.04329061 Heavy Fraction
# 144 H_2.5_13       Firmicutes 0.05270730 Heavy Fraction
# 145 H_2.5_13    Acidobacteria 0.04198274 Heavy Fraction
# 146 H_2.5_13   Planctomycetes 0.01007063 Heavy Fraction
# 147 H_2.5_13  Verrucomicrobia 0.03975935 Heavy Fraction
# 148 H_2.5_13      Chloroflexi 0.00000000 Heavy Fraction
# 149 H_2.5_13              TM6 0.01922574 Heavy Fraction
# 150 H_2.5_13 Gemmatimonadetes 0.00000000 Heavy Fraction
# 151  H_2.5_3   Proteobacteria 0.52669755 Heavy Fraction
# 152  H_2.5_3   Actinobacteria 0.11733512 Heavy Fraction
# 153  H_2.5_3    Bacteroidetes 0.01700597 Heavy Fraction
# 154  H_2.5_3       Firmicutes 0.03309765 Heavy Fraction
# 155  H_2.5_3    Acidobacteria 0.02115080 Heavy Fraction
# 156  H_2.5_3   Planctomycetes 0.04053395 Heavy Fraction
# 157  H_2.5_3  Verrucomicrobia 0.08704133 Heavy Fraction
# 158  H_2.5_3      Chloroflexi 0.00000000 Heavy Fraction
# 159  H_2.5_3              TM6 0.00000000 Heavy Fraction
# 160  H_2.5_3 Gemmatimonadetes 0.00000000 Heavy Fraction
# 161 H_2.5_42   Proteobacteria 0.48654672 Heavy Fraction
# 162 H_2.5_42   Actinobacteria 0.10824530 Heavy Fraction
# 163 H_2.5_42    Bacteroidetes 0.00000000 Heavy Fraction
# 164 H_2.5_42       Firmicutes 0.07972928 Heavy Fraction
# 165 H_2.5_42    Acidobacteria 0.04494057 Heavy Fraction
# 166 H_2.5_42   Planctomycetes 0.02930010 Heavy Fraction
# 167 H_2.5_42  Verrucomicrobia 0.04758171 Heavy Fraction
# 457 S_2.5_14  Verrucomicrobia 0.02050478           Soil
# 458 S_2.5_14      Chloroflexi 0.04564600           Soil
# 459 S_2.5_14              TM6 0.01152578           Soil
# 460 S_2.5_14 Gemmatimonadetes 0.01655402           Soil
# 461 S_2.5_16   Proteobacteria 0.45063445           Soil
# 462 S_2.5_16   Actinobacteria 0.21154180           Soil
# 463 S_2.5_16    Bacteroidetes 0.01825135           Soil
# 464 S_2.5_16       Firmicutes 0.02068486           Soil
# 465 S_2.5_16    Acidobacteria 0.12723796           Soil
# 466 S_2.5_16   Planctomycetes 0.05101686           Soil
# 467 S_2.5_16  Verrucomicrobia 0.02190162           Soil
# 468 S_2.5_16      Chloroflexi 0.03632887           Soil
# 469 S_2.5_16              TM6 0.00000000           Soil
# 470 S_2.5_16 Gemmatimonadetes 0.02442204           Soil
# 471 S_2.5_27   Proteobacteria 0.42445876           Soil
# 472 S_2.5_27   Actinobacteria 0.16826281           Soil
# 473 S_2.5_27    Bacteroidetes 0.01863138           Soil
# 474 S_2.5_27       Firmicutes 0.01909571           Soil
# 475 S_2.5_27    Acidobacteria 0.17551802           Soil
# 476 S_2.5_27   Planctomycetes 0.06396192           Soil
# 477 S_2.5_27  Verrucomicrobia 0.02460967           Soil
# 478 S_2.5_27      Chloroflexi 0.04266063           Soil
# 479 S_2.5_27              TM6 0.00000000           Soil
# 480 S_2.5_27 Gemmatimonadetes 0.02600267           Soil
# 481  S_2.5_3   Proteobacteria 0.37235253           Soil
# 482  S_2.5_3   Actinobacteria 0.35014355           Soil
# 483  S_2.5_3    Bacteroidetes 0.01652132           Soil
# 484  S_2.5_3       Firmicutes 0.02004225           Soil
# 485  S_2.5_3    Acidobacteria 0.05720167           Soil
# 486  S_2.5_3   Planctomycetes 0.02832999           Soil
# 487  S_2.5_3  Verrucomicrobia 0.01717133           Soil
# 488  S_2.5_3      Chloroflexi 0.02589242           Soil
# 489  S_2.5_3              TM6 0.00000000           Soil
# 490  S_2.5_3 Gemmatimonadetes 0.08791506           Soil
# 491 S_2.5_49   Proteobacteria 0.45183881           Soil
# 492 S_2.5_49   Actinobacteria 0.14818827           Soil
# 493 S_2.5_49    Bacteroidetes 0.02536225           Soil
# 494 S_2.5_49       Firmicutes 0.01961657           Soil
# 495 S_2.5_49    Acidobacteria 0.14253932           Soil
# 496 S_2.5_49   Planctomycetes 0.06803892           Soil
# 497 S_2.5_49  Verrucomicrobia 0.04087752           Soil
# 498 S_2.5_49      Chloroflexi 0.03341007           Soil
# 499 S_2.5_49              TM6 0.01034996           Soil
# 500 S_2.5_49 Gemmatimonadetes 0.01601826           Soil
# 501   S_3_12   Proteobacteria 0.46398175           Soil
# 502   S_3_12   Actinobacteria 0.17394928           Soil
# 503   S_3_12    Bacteroidetes 0.01574976           Soil
# 504   S_3_12       Firmicutes 0.01206458           Soil
# 505   S_3_12    Acidobacteria 0.15100465           Soil
# 506   S_3_12   Planctomycetes 0.06979907           Soil
# 507   S_3_12  Verrucomicrobia 0.01961042           Soil
# 508   S_3_12      Chloroflexi 0.03930859           Soil
# 509   S_3_12              TM6 0.00000000           Soil
# 510   S_3_12 Gemmatimonadetes 0.01553040           Soil
# 511   S_3_20   Proteobacteria 0.35160410           Soil
# 512   S_3_20   Actinobacteria 0.29708404           Soil
# 513   S_3_20    Bacteroidetes 0.02383426           Soil
# 514   S_3_20       Firmicutes 0.00000000           Soil
# 515   S_3_20    Acidobacteria 0.09887648           Soil
# 516   S_3_20   Planctomycetes 0.03977789           Soil
# 517   S_3_20  Verrucomicrobia 0.03286141           Soil
# 518   S_3_20      Chloroflexi 0.03692038           Soil
# 519   S_3_20              TM6 0.01035849           Soil
# 520   S_3_20 Gemmatimonadetes 0.07137291           Soil
# 521   S_3_22   Proteobacteria 0.39688433           Soil
# 522   S_3_22   Actinobacteria 0.28597947           Soil
# 523   S_3_22    Bacteroidetes 0.01754386           Soil
# 524   S_3_22       Firmicutes 0.00000000           Soil
# 525   S_3_22    Acidobacteria 0.11993157           Soil
# 526   S_3_22   Planctomycetes 0.04134818           Soil
# 527   S_3_22  Verrucomicrobia 0.02948242           Soil
# 528   S_3_22      Chloroflexi 0.03519691           Soil
# 529   S_3_22              TM6 0.01186576           Soil
# 530   S_3_22 Gemmatimonadetes 0.03170270           Soil
# 531   S_3_23   Proteobacteria 0.36638148           Soil
# 532   S_3_23   Actinobacteria 0.35027680           Soil
# 533   S_3_23    Bacteroidetes 0.00000000           Soil
# 534   S_3_23       Firmicutes 0.02113739           Soil
# 535   S_3_23    Acidobacteria 0.11826875           Soil
# 536   S_3_23   Planctomycetes 0.02767992           Soil
# 537   S_3_23  Verrucomicrobia 0.02667338           Soil
# 538   S_3_23      Chloroflexi 0.02818319           Soil
# 539   S_3_23              TM6 0.00000000           Soil
# 540   S_3_23 Gemmatimonadetes 0.03774534           Soil
# 541   S_3_44   Proteobacteria 0.45695149           Soil
# 542   S_3_44   Actinobacteria 0.17115360           Soil
# 543   S_3_44    Bacteroidetes 0.01781766           Soil
# 544   S_3_44       Firmicutes 0.01794772           Soil
# 545   S_3_44    Acidobacteria 0.14858889           Soil
# 546   S_3_44   Planctomycetes 0.06502796           Soil
# 547   S_3_44  Verrucomicrobia 0.02119912           Soil
# 548   S_3_44      Chloroflexi 0.04584471           Soil
# 549   S_3_44              TM6 0.00000000           Soil
# 550   S_3_44 Gemmatimonadetes 0.01859800           Soil

# %%
# %%R -w 600 -h 400
#
# p = ggplot(d.plot, aes(Trtmt, Abundance, fill = Trtmt))
#
# p = p + geom_boxplot()
#
# p = p + facet_wrap(~Phylum, scales = "free_y",nrow=2)
#
# p = p + scale_fill_manual(values=c("skyblue3","red3","chartreuse4","darkorange","black","gold1"))
#
# p = p + theme_bw()
#
# p = p + guides(fill = "none")
# p = p + theme(legend.position = "none")
#
# p = p + theme(strip.text.x = element_text(size=10, face="italic"),
#               strip.text.y = element_text(size=9),
#                 strip.background = element_rect(colour="white", fill="white"))
#
# p = p + theme(axis.text.x = element_text(size = 9, angle = 45, hjust=1),axis.text.y = element_text(size = 9))
# p = p + theme(axis.title.x = element_blank())
# p = p + theme(axis.title.y = element_text(size = 15, vjust = 1))
#
# p = p + labs(x="Amendment",y="Relative abundance")
#
# p

# %%
# %%R
# ggsave(filename="RelabundPhylum16S2MonthsBox.jpg", p, width=7, height=4)

# %%
# %%R
# m = SampTrtmt%>%
#     group_by(Trtmt)%>%
#     summarize(count=n())
# m
# Out:
# Source: local data frame [5 x 2]
#
#            Trtmt count
# 1   Ferrihydrite    14
# 2         Quartz    14
# 3      Kaolinite    13
# 4 Heavy Fraction     3
# 5           Soil    11

# %%
# %%R
# Phyla = unique(d.plot$Phylum)
# Phyla
# Out:
#  [1] Proteobacteria   Actinobacteria   Bacteroidetes    Firmicutes
#  [5] Acidobacteria    Planctomycetes   Verrucomicrobia  Chloroflexi
#  [9] TM6              Gemmatimonadetes
# 10 Levels: Proteobacteria Actinobacteria Bacteroidetes ... Gemmatimonadetes

# %%
# %%R
# for(i in Phyla){
#     a = d.plot%>%
#         filter(Phylum==i)
#     anova=aov(a$Abundance~a$Trtmt)
#     Tukey=TukeyHSD(anova)
#     print(i)
#     print(summary(anova))
#     print(Tukey)}
# Out:
# [1] "Proteobacteria"
#             Df Sum Sq Mean Sq F value  Pr(>F)
# a$Trtmt      4 0.2692 0.06730    5.08 0.00163 **
# Residuals   50 0.6625 0.01325
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = a$Abundance ~ a$Trtmt)
#
# $`a$Trtmt`
#                                     diff         lwr          upr     p adj
# Quartz-Ferrihydrite         -0.119232468 -0.24234603  0.003881099 0.0619440
# Kaolinite-Ferrihydrite      -0.009680497 -0.13513929  0.115778301 0.9994771
# Heavy Fraction-Ferrihydrite -0.062517336 -0.26974835  0.144713677 0.9121720
# Soil-Ferrihydrite           -0.174123877 -0.30536338 -0.042884374 0.0039740
# Kaolinite-Quartz             0.109551970 -0.01590683  0.235010768 0.1137990
# Heavy Fraction-Quartz        0.056715132 -0.15051588  0.263946145 0.9367834
# Soil-Quartz                 -0.054891409 -0.18613091  0.076348094 0.7606147
# Heavy Fraction-Kaolinite    -0.052836838 -0.26146966  0.155795978 0.9517044
# Soil-Kaolinite              -0.164443380 -0.29788538 -0.031001382 0.0086997
# Soil-Heavy Fraction         -0.111606541 -0.32376580  0.100552714 0.5745323
#
# [1] "Actinobacteria"
#             Df Sum Sq Mean Sq F value  Pr(>F)
# a$Trtmt      4 0.1320 0.03299   4.804 0.00234 **
# Residuals   50 0.3434 0.00687
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = a$Abundance ~ a$Trtmt)
#
# $`a$Trtmt`
#                                    diff         lwr         upr     p adj
# Quartz-Ferrihydrite          0.05581476 -0.03282294  0.14445246 0.3952920
# Kaolinite-Ferrihydrite      -0.05180275 -0.14212894  0.03852344 0.4901964
# Heavy Fraction-Ferrihydrite -0.02962423 -0.17882372  0.11957525 0.9799205
# Soil-Ferrihydrite            0.07644714 -0.01804097  0.17093525 0.1653645
# Kaolinite-Quartz            -0.10761751 -0.19794370 -0.01729132 0.0120695
# Heavy Fraction-Quartz       -0.08543899 -0.23463848  0.06376049 0.4916985
# Soil-Quartz                  0.02063238 -0.07385573  0.11512049 0.9715587
# Heavy Fraction-Kaolinite     0.02217852 -0.12803022  0.17238726 0.9934186
# Soil-Kaolinite               0.12824989  0.03217606  0.22432372 0.0037081
# Soil-Heavy Fraction          0.10607137 -0.04667629  0.25881903 0.2978083
#
# [1] "Bacteroidetes"
#             Df  Sum Sq  Mean Sq F value Pr(>F)
# a$Trtmt      4 0.03876 0.009689   2.072 0.0985 .
# Residuals   50 0.23381 0.004676
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = a$Abundance ~ a$Trtmt)
#
# $`a$Trtmt`
#                                     diff         lwr         upr     p adj
# Quartz-Ferrihydrite         -0.020064807 -0.09320508 0.053075471 0.9362650
# Kaolinite-Ferrihydrite      -0.042993247 -0.11752680 0.031540305 0.4843913
# Heavy Fraction-Ferrihydrite -0.068301142 -0.19141457 0.054812291 0.5232149
# Soil-Ferrihydrite           -0.071298410 -0.14926621 0.006669389 0.0881078
# Kaolinite-Quartz            -0.022928440 -0.09746199 0.051605112 0.9063194
# Heavy Fraction-Quartz       -0.048236335 -0.17134977 0.074877098 0.8011666
# Soil-Quartz                 -0.051233603 -0.12920140 0.026734196 0.3521981
# Heavy Fraction-Kaolinite    -0.025307895 -0.14925412 0.098638333 0.9777424
# Soil-Kaolinite              -0.028305163 -0.10758144 0.050971111 0.8494011
# Soil-Heavy Fraction         -0.002997268 -0.12903851 0.123043974 0.9999952
#
# [1] "Firmicutes"
#             Df  Sum Sq  Mean Sq F value   Pr(>F)
# a$Trtmt      4 0.06885 0.017214   9.568 7.98e-06 ***
# Residuals   50 0.08995 0.001799
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = a$Abundance ~ a$Trtmt)
#
# $`a$Trtmt`
#                                     diff         lwr         upr     p adj
# Quartz-Ferrihydrite          0.073201717  0.02783593  0.11856751 0.0003045
# Kaolinite-Ferrihydrite       0.064545679  0.01831570  0.11077566 0.0021855
# Heavy Fraction-Ferrihydrite  0.032240105 -0.04412190  0.10860211 0.7543167
# Soil-Ferrihydrite           -0.007579641 -0.05593974  0.04078045 0.9917347
# Kaolinite-Quartz            -0.008656038 -0.05488602  0.03757394 0.9838475
# Heavy Fraction-Quartz       -0.040961611 -0.11732361  0.03540039 0.5559707
# Soil-Quartz                 -0.080781358 -0.12914145 -0.03242126 0.0001783
# Heavy Fraction-Kaolinite    -0.032305573 -0.10918412  0.04457298 0.7574916
# Soil-Kaolinite              -0.072125319 -0.12129701 -0.02295363 0.0011697
# Soil-Heavy Fraction         -0.039819746 -0.11799774  0.03835825 0.6044572
#
# [1] "Acidobacteria"
#             Df  Sum Sq  Mean Sq F value   Pr(>F)
# a$Trtmt      4 0.08842 0.022104   23.89 4.34e-11 ***
# Residuals   50 0.04625 0.000925
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = a$Abundance ~ a$Trtmt)
#
# $`a$Trtmt`
#                                     diff          lwr        upr     p adj
# Quartz-Ferrihydrite          0.007898192 -0.024632074 0.04042846 0.9583800
# Kaolinite-Ferrihydrite       0.038090757  0.004940811 0.07124070 0.0168077
# Heavy Fraction-Ferrihydrite  0.014159843 -0.040596755 0.06891644 0.9480444
# Soil-Ferrihydrite            0.108655313  0.073977933 0.14333269 0.0000000
# Kaolinite-Quartz             0.030192565 -0.002957382 0.06334251 0.0901805
# Heavy Fraction-Quartz        0.006261651 -0.048494947 0.06101825 0.9975484
# Soil-Quartz                  0.100757121  0.066079741 0.13543450 0.0000000
# Heavy Fraction-Kaolinite    -0.023930914 -0.079057910 0.03119608 0.7349795
# Soil-Kaolinite               0.070564557  0.035305212 0.10582390 0.0000070
# Soil-Heavy Fraction          0.094495471  0.038436685 0.15055426 0.0001542
#
# [1] "Planctomycetes"
#             Df  Sum Sq   Mean Sq F value   Pr(>F)
# a$Trtmt      4 0.01022 0.0025548   11.32 1.29e-06 ***
# Residuals   50 0.01128 0.0002257
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = a$Abundance ~ a$Trtmt)
#
# $`a$Trtmt`
#                                     diff          lwr         upr     p adj
# Quartz-Ferrihydrite         -0.001696549 -0.017764625 0.014371527 0.9982044
# Kaolinite-Ferrihydrite      -0.007343307 -0.023717469 0.009030855 0.7110277
# Heavy Fraction-Ferrihydrite  0.005715258 -0.021331344 0.032761859 0.9747613
# Soil-Ferrihydrite            0.030738122  0.013609496 0.047866748 0.0000541
# Kaolinite-Quartz            -0.005646758 -0.022020920 0.010727404 0.8647733
# Heavy Fraction-Quartz        0.007411807 -0.019634795 0.034458408 0.9364996
# Soil-Quartz                  0.032434671  0.015306045 0.049563297 0.0000205
# Heavy Fraction-Kaolinite     0.013058565 -0.014170993 0.040288122 0.6573368
# Soil-Kaolinite               0.038081429  0.020665346 0.055497512 0.0000011
# Soil-Heavy Fraction          0.025022864 -0.002666943 0.052712672 0.0943045
#
# [1] "Verrucomicrobia"
#             Df   Sum Sq   Mean Sq F value   Pr(>F)
# a$Trtmt      4 0.004744 0.0011861   5.462 0.000996 ***
# Residuals   50 0.010857 0.0002171
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = a$Abundance ~ a$Trtmt)
#
# $`a$Trtmt`
#                                     diff         lwr          upr     p adj
# Quartz-Ferrihydrite          0.001413220 -0.01434777  0.017174208 0.9990544
# Kaolinite-Ferrihydrite      -0.002810269 -0.01887149  0.013250955 0.9874652
# Heavy Fraction-Ferrihydrite  0.039594657  0.01306496  0.066124354 0.0009285
# Soil-Ferrihydrite            0.006409164 -0.01039211  0.023210433 0.8161511
# Kaolinite-Quartz            -0.004223489 -0.02028471  0.011837736 0.9449272
# Heavy Fraction-Quartz        0.038181438  0.01165174  0.064711134 0.0014964
# Soil-Quartz                  0.004995944 -0.01180533  0.021797214 0.9162905
# Heavy Fraction-Kaolinite     0.042404927  0.01569577  0.069114082 0.0003878
# Soil-Kaolinite               0.009219433 -0.00786380  0.026302666 0.5501332
# Soil-Heavy Fraction         -0.033185494 -0.06034610 -0.006024884 0.0094693
#
# [1] "Chloroflexi"
#             Df   Sum Sq   Mean Sq F value   Pr(>F)
# a$Trtmt      4 0.005111 0.0012777   8.642 2.21e-05 ***
# Residuals   50 0.007392 0.0001478
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = a$Abundance ~ a$Trtmt)
#
# $`a$Trtmt`
#                                     diff          lwr           upr     p adj
# Quartz-Ferrihydrite          0.009192096 -0.003812959  0.0221971504 0.2809282
# Kaolinite-Ferrihydrite       0.011405490 -0.001847302  0.0246582827 0.1227584
# Heavy Fraction-Ferrihydrite -0.012131945 -0.034022714  0.0097588241 0.5242421
# Soil-Ferrihydrite            0.024268012  0.010404577  0.0381314475 0.0000829
# Kaolinite-Quartz             0.002213395 -0.011039398  0.0154661872 0.9894826
# Heavy Fraction-Quartz       -0.021324041 -0.043214810  0.0005667286 0.0596438
# Soil-Quartz                  0.015075917  0.001212482  0.0289393519 0.0267623
# Heavy Fraction-Kaolinite    -0.023537435 -0.045576284 -0.0014985872 0.0308710
# Soil-Kaolinite               0.012862522 -0.001233573  0.0269586168 0.0892156
# Soil-Heavy Fraction          0.036399958  0.013988595  0.0588113197 0.0002757
#
# [1] "TM6"
#             Df   Sum Sq   Mean Sq F value Pr(>F)
# a$Trtmt      4 0.001507 0.0003767   2.576 0.0487 *
# Residuals   50 0.007313 0.0001463
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = a$Abundance ~ a$Trtmt)
#
# $`a$Trtmt`
#                                      diff          lwr          upr     p adj
# Quartz-Ferrihydrite         -0.0103819620 -0.023317458 0.0025535344 0.1714256
# Kaolinite-Ferrihydrite      -0.0130909865 -0.026272895 0.0000909224 0.0524266
# Heavy Fraction-Ferrihydrite  0.0007045195 -0.021069165 0.0224782044 0.9999835
# Soil-Ferrihydrite           -0.0074757864 -0.021265072 0.0063134991 0.5457242
# Kaolinite-Quartz            -0.0027090245 -0.015890933 0.0104728844 0.9772068
# Heavy Fraction-Quartz        0.0110864815 -0.010687203 0.0328601664 0.6047763
# Soil-Quartz                  0.0029061756 -0.010883110 0.0166954611 0.9750028
# Heavy Fraction-Kaolinite     0.0137955060 -0.008125466 0.0357164780 0.3958840
# Soil-Kaolinite               0.0056152002 -0.008405501 0.0196359009 0.7881787
# Soil-Heavy Fraction         -0.0081803059 -0.030471799 0.0141111876 0.8362708
#
# [1] "Gemmatimonadetes"
#             Df   Sum Sq   Mean Sq F value   Pr(>F)
# a$Trtmt      4 0.007021 0.0017553   8.148 3.86e-05 ***
# Residuals   50 0.010771 0.0002154
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = a$Abundance ~ a$Trtmt)
#
# $`a$Trtmt`
#                                     diff          lwr        upr     p adj
# Quartz-Ferrihydrite         -0.003071062 -0.018769645 0.01262752 0.9809933
# Kaolinite-Ferrihydrite       0.006734601 -0.009263029 0.02273223 0.7562792
# Heavy Fraction-Ferrihydrite -0.005825370 -0.032250023 0.02059928 0.9705579
# Soil-Ferrihydrite            0.027189908  0.010455162 0.04392465 0.0002742
# Kaolinite-Quartz             0.009805663 -0.006191967 0.02580329 0.4227632
# Heavy Fraction-Quartz       -0.002754309 -0.029178962 0.02367034 0.9982927
# Soil-Quartz                  0.030260970  0.013526224 0.04699572 0.0000473
# Heavy Fraction-Kaolinite    -0.012559972 -0.039163373 0.01404343 0.6703897
# Soil-Kaolinite               0.020455306  0.003439714 0.03747090 0.0110850
# Soil-Heavy Fraction          0.033015278  0.005962210 0.06006835 0.0095793

# %%
# %%R
